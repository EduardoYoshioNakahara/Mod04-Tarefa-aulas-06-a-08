# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
data_json = r.json()
data_json
df = pd.DataFrame(data_json['items'])
df_rj = df[df['uf']== 'RJ']
df_rj
# Out:
#       id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 7         11692        Município     Rio de Janeiro   3304557  RJ
# 36        47509        Município  Casimiro de Abreu   3301306  RJ
# 85        42271        Município     Barra do Piraí   3300308  RJ
# 203       13669        Município         Petrópolis   3303906  RJ
# 226       11589        Município            Niterói   3303302  RJ
# ...         ...              ...                ...       ...  ..
# 4428      45530        Município  Casimiro de Abreu   3301306  RJ
# 4498      42266        Município    Paty do Alferes   3303856  RJ
# 4702      20535        Município     Rio de Janeiro   3304557  RJ
# 4920      13004        Município             Quatis   3304128  RJ
# 4927      61653        Município        Teresópolis   3305802  RJ
#
#                    num_pvl                                             status  \
# 7                     None                                           Deferido
# ...

# %%
# 2) Seu código aqui
colunas = df.columns
colunas
status = df_rj['status'].value_counts()
status

#Deferido                                                 22
#Arquivado                                                16
#Encaminhado à PGFN com manifestação técnica favorável    13
# Out:
# status
# Deferido                                                 37
# Deferido (PVL-IF)                                         9
# Encaminhado à PGFN com manifestação técnica favorável     7
# Regularizado                                              7
# Arquivado por decurso de prazo                            7
# Arquivado                                                 5
# Em retificação pelo interessado                           3
# Arquivado a pedido                                        3
# Arquivado pela STN                                        1
# Assinado pelo interessado (retificação)                   1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
ano_status = df_rj['data_status'].astype(str)
ano_status = ano_status.str.split('/').str[-1]
ano_status.value_counts()
# Out:
# data_status
# 2007    9
# 2023    8
# 2012    7
# 2019    6
# 2011    6
# 2020    5
# 2008    5
# 2021    4
# 2017    3
# 2010    3
# 2022    3
# 2016    3
# 2024    3
# 2014    3
# 2002    3
# 2006    2
# 2015    2
# 2013    2
# 2009    2
# 2004    1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def pesquisa_uf():
    uf = input('insira o uf que deseja pesquisar: ')
    df_uf = df[df['uf'] == uf]
    return df_uf
    
pesquisa_uf()
# Out:
# insira o uf que deseja pesquisar:  MG
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 2          5533        Município             Japaraíba   3135308  MG
# 3          5694        Município  Governador Valadares   3127701  MG
# 8         13567        Município       Várzea da Palma   3170800  MG
# 9         13605        Município               Jequeri   3135506  MG
# 12         8899        Município        Franciscópolis   3126752  MG
# ...         ...              ...                   ...       ...  ..
# 4987      26118        Município                Toledo   3169109  MG
# 4988      26507        Município  São João das Missões   3162450  MG
# 4989      26524        Município             Jequitibá   3135704  MG
# 4996      26617        Município   Carmópolis de Minas   3114501  MG
# 4998      26610        Município         Inconfidentes   3130606  MG
#
#                    num_pvl             status          num_processo  \
# ...

# %%
# 2) Seu código aqui
status = df[df['status'] == 'Arquivado por decurso de prazo']
status.value_counts()
#79 consultas
# Out:
# id_pleito  tipo_interessado  interessado        cod_ibge  uf  num_pvl               status                          num_processo          data_protocolo        tipo_operacao                                        finalidade                                                     tipo_credor                      credor                                                moeda  valor        pvl_assoc_divida  pvl_contradado_credor  data_status
# 19194      Município         Carapicuíba        3510609   SP  00000.000000/2010-60  Arquivado por decurso de prazo  17944.000587/2015-94  2017-02-10T02:00:00Z  Operação contratual interna                          PMAT                                                           Instituição Financeira Nacional  Banco Nacional de Desenvolvimento Econômico e Social  Real   40000000.0   0                 0                      21/08/2017     1
# ...

# %%
# 3) Seu código aqui
estados = df['uf']
estados.value_counts()

consulta_muni_ba = df[df['uf'] == 'BA']
consulta_muni_ba = consulta_muni_ba[consulta_muni_ba['tipo_interessado'] == 'Município']
consulta_muni_ba['interessado'].value_counts()
#Luís Eduardo Magalhães    5
#Salvador                  5
#Irecê                     5
# Out:
# interessado
# Luís Eduardo Magalhães    5
# Salvador                  5
# Irecê                     5
# Barreiras                 4
# Lauro de Freitas          4
#                          ..
# Belmonte                  1
# Nilo Peçanha              1
# Poções                    1
# Itagibá                   1
# Brumado                   1
# Name: count, Length: 154, dtype: int64

# %%
# 4) Seu código aqui

consulta_muni_ba.to_csv('bahia.csv')
